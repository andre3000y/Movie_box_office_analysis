# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('data/cln4_tn.movie_budgets.csv')
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0              0             0   1  Dec 18, 2009
# 1              1             1   2  May 20, 2011
# 2              2             2   3   Jun 7, 2019
# 3              3             3   4   May 1, 2015
# 4              4             4   5  Dec 15, 2017
# ...          ...           ...  ..           ...
# 5228        5775          5775  76  May 26, 2006
# 5229        5776          5776  77  Dec 31, 2004
# 5230        5778          5778  79   Apr 2, 1999
# 5231        5779          5779  80  Jul 13, 2005
# 5232        5781          5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
# df['production_budget'] = df['production_budget'].str.replace(',', '')
# df['production_budget'] = df['production_budget'].str.replace('$', '')

# %%
df.drop(194, inplace = True)

# %%
#df['worldwide_gross'] = df['worldwide_gross'].str.replace(',', '')
#df['worldwide_gross'] = df['worldwide_gross'].str.replace('$', '')
#df['worldwide_gross'] = df['worldwide_gross'].map(int)
#df['production_budget'] = df['production_budget'].map(int)

# %%
df["profit"] = df["worldwide_gross"]-df["production_budget"]

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0           0             0   1  Dec 18, 2009
# 1           1             1   2  May 20, 2011
# 2           2             2   3   Jun 7, 2019
# 3           3             3   4   May 1, 2015
# 4           4             4   5  Dec 15, 2017
#
#                                          movie  production_budget  \
# 0                                       Avatar          425000000
# 1  Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                 Dark Phoenix          350000000
# 3                      Avengers: Age of Ultron          330600000
# 4            Star Wars Ep. VIII: The Last Jedi          317000000
#
#    domestic_gross  worldwide_gross      profit  profit_as_percentage
# 0       760507625       2776345279  2351345279            553.257713
# 1       241063875       1045663875   635063875            154.667286
# 2        42762350        149762350  -200237650            -57.210757
# ...

# %%
#df['domestic_gross'] = df['domestic_gross'].str.replace(',', '')
#df['domestic_gross'] = df['domestic_gross'].str.replace('$', '')
#df['domestic_gross'] = df['domestic_gross'].map(int)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0           0             0   1  Dec 18, 2009
# 1           1             1   2  May 20, 2011
# 2           2             2   3   Jun 7, 2019
# 3           3             3   4   May 1, 2015
# 4           4             4   5  Dec 15, 2017
#
#                                          movie  production_budget  \
# 0                                       Avatar          425000000
# 1  Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                 Dark Phoenix          350000000
# 3                      Avengers: Age of Ultron          330600000
# 4            Star Wars Ep. VIII: The Last Jedi          317000000
#
#    domestic_gross  worldwide_gross      profit  profit_as_percentage
# 0       760507625       2776345279  2351345279            553.257713
# 1       241063875       1045663875   635063875            154.667286
# 2        42762350        149762350  -200237650            -57.210757
# ...

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0              0             0   1  Dec 18, 2009
# 1              1             1   2  May 20, 2011
# 2              2             2   3   Jun 7, 2019
# 3              3             3   4   May 1, 2015
# 4              4             4   5  Dec 15, 2017
# ...          ...           ...  ..           ...
# 5228        5775          5775  76  May 26, 2006
# 5229        5776          5776  77  Dec 31, 2004
# 5230        5778          5778  79   Apr 2, 1999
# 5231        5779          5779  80  Jul 13, 2005
# 5232        5781          5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# ...

# %%
df.sort_values("profit")
# Out:
#      Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 2             2             2   3   Jun 7, 2019
# 193         193           193  94  Mar 11, 2011
# 340         341           341  42  Jun 14, 2019
# 351         352           352  53  Apr 27, 2001
# 403         404           404   5  Aug 16, 2002
# ..          ...           ...  ..           ...
# 33           33            33  34  Jun 12, 2015
# 5             5             5   6  Dec 18, 2015
# 6             6             6   7  Apr 27, 2018
# 42           42            42  43  Dec 19, 1997
# 0             0             0   1  Dec 18, 2009
#
#                                     movie  production_budget  domestic_gross  \
# 2                            Dark Phoenix          350000000        42762350
# 193                       Mars Needs Moms          150000000        21392758
# 340           Men in Black: International          110000000         3100000
# ...

# %%
import seaborn as sns
sns.set(style='darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %%
profit = df["profit"]
movie = df["movie"]

# %%
sns.histplot(data=profit)
# Out:
# <AxesSubplot:xlabel='profit', ylabel='Count'>

# %%
production_budget = df["production_budget"]

# %%
correlation = profit.corr(production_budget)
print(correlation)
# Out:
# 0.6060632110648573

# %% [markdown]
# # Correlation between production budget and profit is .606

# %%
df.to_csv(path_or_buf="cln2_tn.movie_budgets.csv")

# %%
# Out:
# [[1.         0.60606321]
#  [0.60606321 1.        ]]

# %%
df["profit_as_percentage"] = df["profit"]/ df["production_budget"] *100
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0              0             0   1  Dec 18, 2009
# 1              1             1   2  May 20, 2011
# 2              2             2   3   Jun 7, 2019
# 3              3             3   4   May 1, 2015
# 4              4             4   5  Dec 15, 2017
# ...          ...           ...  ..           ...
# 5228        5775          5775  76  May 26, 2006
# 5229        5776          5776  77  Dec 31, 2004
# 5230        5778          5778  79   Apr 2, 1999
# 5231        5779          5779  80  Jul 13, 2005
# 5232        5781          5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# ...

# %%
df = df.loc[df['worldwide_gross'] != 0]
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0              0             0   1  Dec 18, 2009
# 1              1             1   2  May 20, 2011
# 2              2             2   3   Jun 7, 2019
# 3              3             3   4   May 1, 2015
# 4              4             4   5  Dec 15, 2017
# ...          ...           ...  ..           ...
# 5228        5775          5775  76  May 26, 2006
# 5229        5776          5776  77  Dec 31, 2004
# 5230        5778          5778  79   Apr 2, 1999
# 5231        5779          5779  80  Jul 13, 2005
# 5232        5781          5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# ...

# %%
df.to_csv(path_or_buf="cln3_tn.movie_budgets.csv")

# %%
df.sort_values("profit_as_percentage")
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 3682        3818          3818  19   May 8, 2015
# 2111        2152          2152  53  Aug 24, 1997
# 4703        5027          5027  28   Jan 1, 1993
# 1227        1242          1242  43   Nov 1, 2013
# 4928        5298          5298  99  Dec 13, 2002
# ...          ...           ...  ..           ...
# 4986        5406          5406   7  Jul 14, 1999
# 5171        5679          5679  80  Jul 10, 2015
# 5040        5492          5492  93  Sep 25, 2009
# 5126        5613          5613  14  Mar 21, 1980
# 5211        5745          5745  46  Jun 30, 1972
#
#                                movie  production_budget  domestic_gross  \
# 3682                      Skin Trade            9000000            1242
# 2111  The Grimm Brothers' Snow White           26000000            5000
# 4703          Ed and his Dead Mother            1800000             673
# 1227                      Mr. Nobody           46500000            3622
# ...

# %%
df.sort_values("profit_as_percentage")
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 3682        3818          3818  19   May 8, 2015
# 2111        2152          2152  53  Aug 24, 1997
# 4703        5027          5027  28   Jan 1, 1993
# 1227        1242          1242  43   Nov 1, 2013
# 4928        5298          5298  99  Dec 13, 2002
# ...          ...           ...  ..           ...
# 4986        5406          5406   7  Jul 14, 1999
# 5171        5679          5679  80  Jul 10, 2015
# 5040        5492          5492  93  Sep 25, 2009
# 5126        5613          5613  14  Mar 21, 1980
# 5211        5745          5745  46  Jun 30, 1972
#
#                                movie  production_budget  domestic_gross  \
# 3682                      Skin Trade            9000000            1242
# 2111  The Grimm Brothers' Snow White           26000000            5000
# 4703          Ed and his Dead Mother            1800000             673
# 1227                      Mr. Nobody           46500000            3622
# ...

# %%
df = df.loc[df['domestic_gross'] != 0]
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 0              0             0   1  Dec 18, 2009
# 1              1             1   2  May 20, 2011
# 2              2             2   3   Jun 7, 2019
# 3              3             3   4   May 1, 2015
# 4              4             4   5  Dec 15, 2017
# ...          ...           ...  ..           ...
# 5228        5775          5775  76  May 26, 2006
# 5229        5776          5776  77  Dec 31, 2004
# 5230        5778          5778  79   Apr 2, 1999
# 5231        5779          5779  80  Jul 13, 2005
# 5232        5781          5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# ...

# %%
df.sort_values("profit_as_percentage")
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 3682        3818          3818  19   May 8, 2015
# 2111        2152          2152  53  Aug 24, 1997
# 4703        5027          5027  28   Jan 1, 1993
# 1227        1242          1242  43   Nov 1, 2013
# 4928        5298          5298  99  Dec 13, 2002
# ...          ...           ...  ..           ...
# 4986        5406          5406   7  Jul 14, 1999
# 5171        5679          5679  80  Jul 10, 2015
# 5040        5492          5492  93  Sep 25, 2009
# 5126        5613          5613  14  Mar 21, 1980
# 5211        5745          5745  46  Jun 30, 1972
#
#                                movie  production_budget  domestic_gross  \
# 3682                      Skin Trade            9000000            1242
# 2111  The Grimm Brothers' Snow White           26000000            5000
# 4703          Ed and his Dead Mother            1800000             673
# 1227                      Mr. Nobody           46500000            3622
# ...

# %%
df.drop(4081, inplace = True)

# %%
df.sort_values("profit_as_percentage", ascending=False)
# Out:
#       Unnamed: 0  Unnamed: 0.1  id  release_date  \
# 5211        5745          5745  46  Jun 30, 1972
# 5126        5613          5613  14  Mar 21, 1980
# 5040        5492          5492  93  Sep 25, 2009
# 5171        5679          5679  80  Jul 10, 2015
# 4986        5406          5406   7  Jul 14, 1999
# ...          ...           ...  ..           ...
# 4928        5298          5298  99  Dec 13, 2002
# 1227        1242          1242  43   Nov 1, 2013
# 4703        5027          5027  28   Jan 1, 1993
# 2111        2152          2152  53  Aug 24, 1997
# 3682        3818          3818  19   May 8, 2015
#
#                                movie  production_budget  domestic_gross  \
# 5211                     Deep Throat              25000        45000000
# 5126                         Mad Max             200000         8750000
# 5040             Paranormal Activity             450000       107918810
# 5171                     The Gallows             100000        22764410
# ...

# %%
data = pd.read_csv('data/cln4_tn.movie_budgets.csv')
x = data['profit']
y = data['production_budget']

print(np.corrcoef(x, y))

plt.scatter(x, y) 
plt.title('Correlation between production budget and profit')
plt.xlabel('profit')
plt.ylabel('production budget')
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)), color='yellow')
plt.show()
# Out:
# [[1.         0.60552241]
#  [0.60552241 1.        ]]

# %%
df

# %%
df.drop(['Unnamed: 0','Unnamed: 0.1'], inplace = True, axis = 1)
df.head()

# %%
df.sort_values("profit_as_percentage", ascending=False).head(11)

# %% [markdown]
# # 5 of the top 11 profit as percent movies are horror movie

# %%
df.sort_values("profit", ascending=False).head(10)

# %% [markdown]
# # 9 out the top 10 for total profit are Action movies

# %%
profit_as_percentage = df["profit_as_percentage"]

# %%
correlation = profit_as_percentage.corr(production_budget)
print(correlation)
# Out:
# -0.058968715719257575

# %% [markdown]
# # Correlation between production budget and prof

# %%
sns.histplot(data=profit_as_percentage)
# Out:
# <AxesSubplot:xlabel='profit_as_percentage', ylabel='Count'>
