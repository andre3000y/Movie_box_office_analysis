# %%
import pandas as pd
df = pd.read_csv("cln3_tn.movie_budgets.csv")
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  id  release_date  \
# 0              0             0               0   1  Dec 18, 2009
# 1              1             1               1   2  May 20, 2011
# 2              2             2               2   3   Jun 7, 2019
# 3              3             3               3   4   May 1, 2015
# 4              4             4               4   5  Dec 15, 2017
# ...          ...           ...             ...  ..           ...
# 5227        5228          5775            5775  76  May 26, 2006
# 5228        5229          5776            5776  77  Dec 31, 2004
# 5229        5230          5778            5778  79   Apr 2, 1999
# 5230        5231          5779            5779  80  Jul 13, 2005
# 5231        5232          5781            5781  82   Aug 5, 2005
#
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# ...
